# %% [markdown]
# # Pandas Practice
# This is to practice my pandas skills! I will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle!

# %%
import pandas as pd
sal = pd.read_csv('Salaries.csv')

# %%
sal
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %% [markdown]
# ** How many entries are there? **

# %%
sal.info() #148654 Entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the avarage BasePay?**

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %% [markdown]
# **What is the highest OvertimePay?**

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# **How to find jobtitle of someone in dataset? Let say David M Turner**

# %%
sal[sal['EmployeeName'] == 'David M Turner']['JobTitle']
# Out:
# 94797     Transit Car Cleaner
# 148634    Transit Car Cleaner
# Name: JobTitle, dtype: object

# %% [markdown]
# **How to find someone's jobtittle in dataset? Let say General Laborer**

# %%
sal[sal['JobTitle']== 'General Laborer']['EmployeeName']
# Out:
# 46838                    David Linney
# 49214                   William Smith
# 50163                Nicholas DeRenzi
# 50267                    Tino Laulusa
# 50370                 Jerold Robinson
# 51742                  Kenneth Helmer
# 51747                       Gary Reid
# 51960                    Edwin Gipson
# 52452                  Renato Soriano
# 52879                   Anthony Umali
# 53376                 Eduardo Pacheco
# 53389                  Alonzo Simpson
# 53671     Ricardo Zaragoza-Cabrera Jr
# 53763                 Timothy Alemany
# 53856                Lawrence Peoples
# 53939             Waldemar Medolinski
# 54134                 Jermaine Joseph
# 54211                   Larry Montoya
# 54251                     John Miller
# 54276                  Gerardo Campos
# 54296                Patrick Flaherty
# 54329                   Uera Smith-Jr
# 54500                     David Gibbs
# 54512                 Antonio Pacheco
# 54518                 Jared Adam Work
# ...

# %% [markdown]
# There is 1033 people who have jobtitle as Genereal Laborer

# %% [markdown]
# **How much does David M Turner make (including benefits)?**

# %%
sal[sal['EmployeeName']=='David M Turner']['TotalPayBenefits']
# Out:
# 94797     90095.47
# 148634        0.00
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# **Who is the highest paid person (including benefits)?**

# %%
sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %% [markdown]
# **Who is the lowest paid person (including benefits)?**

# %%
sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %% [markdown]
# Why is it minus? idk

# %% [markdown]
# **What is the averege pay Basepay of all employees per year? (2011-2014)**

# %%
sal.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# **What is the averege pay Basepay of all employees based on Jobtitles? (2011-2014)**

# %%
sal.groupby('JobTitle').mean()['BasePay']
# Out:
# JobTitle
# ACCOUNT CLERK                                          43300.806506
# ACCOUNTANT                                             46643.172000
# ACCOUNTANT INTERN                                      28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                            62290.780000
# ACUPUNCTURIST                                          66374.400000
# ADMINISTRATIVE ANALYST                                 63435.628602
# ADMINISTRATIVE ANALYST II                              59373.710000
# ADMINISTRATIVE ANALYST III                             92698.515000
# ADMINISTRATIVE ENGINEER                               120913.161000
# ADMINISTRATIVE SERVICES MANAGER                        75555.033333
# ADMINISTRATOR, SFGH MEDICAL CENTER                    245124.440000
# AFFIRMATIVE ACTION SPECIALIST                          68177.316667
# AGRICULTURAL INSPECTOR                                 53274.100000
# AIRPORT ASSISTANT DEPUTY DIRECTOR, BUSINESS ADMINI      1927.500000
# ...

# %% [markdown]
# **How many unique jobtitles?**

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# **What are the 10 types most common jobs?**

# %%
sal['JobTitle'].value_counts().head(10)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Custodian                       2418
# TRANSIT OPERATOR                2388
# Firefighter                     2359
# Recreation Leader               1971
# Patient Care Assistant          1945
# Name: JobTitle, dtype: int64

# %% [markdown]
# **How many job titles were represented by only person in 2014?**

# %%
sum(sal[sal['Year'] == 2013]['JobTitle'].value_counts() == 1)
# Out:
# 202

# %% [markdown]
# **How many people have the word Chief in their Job titles?**

# %%
def chief_string(title):
    if 'chief' in title.lower():
        return True
    else:
        return False

# %%
sum(sal['JobTitle'].apply(lambda x: chief_string(x)))
# Out:
# 627

# %% [markdown]
# **Thanks**
